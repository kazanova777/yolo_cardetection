# %%
from ultralytics import YOLO

# Загружаем свою модель
model = YOLO("best.pt")

model.predict(
    source="E:/projects/yolo_cardetection/тест",  # путь к папке с изображениями
    save=True,
    save_txt=True,
    conf=0.25
)
# Out:
# image 1/6 E:\projects\yolo_cardetection\\IMG_5468.JPG: 640x480 1 licence, 106.9ms
# image 2/6 E:\projects\yolo_cardetection\\IMG_5469.JPG: 640x480 1 licence, 74.8ms
# image 3/6 E:\projects\yolo_cardetection\\IMG_5470.JPG: 640x480 1 licence, 77.3ms
# image 4/6 E:\projects\yolo_cardetection\\IMG_5471.JPG: 640x480 (no detections), 75.1ms
# image 5/6 E:\projects\yolo_cardetection\\IMG_5473.JPG: 640x480 1 licence, 75.1ms
# image 6/6 E:\projects\yolo_cardetection\\IMG_5474.JPG: 640x480 1 licence, 84.5ms
# Speed: 2.9ms preprocess, 82.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict
# 5 labels saved to runs\detect\predict\labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'licence'}
#  obb: None
#  orig_img: array([[[160, 150, 140],
#          [160, 150, 140],
#          [161, 151, 141],
#          ...,
# ...
